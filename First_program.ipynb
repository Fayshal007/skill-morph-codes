# %% [markdown]
# <a href="https://colab.research.google.com/github/Fayshal007/skill-morph-codes/blob/main/First_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello skill morph. this is fayshal. my id SM-ML-2026-B2-036")
# Out:
# hello skill morph. this is fayshal. my id SM-ML-2026-B2-036
